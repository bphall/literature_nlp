# %%
import pdftotext
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk import word_tokenize
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(0)
from gensim.models import Word2Vec

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/braytonhall/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
with open("war_and_peace.pdf", "rb") as f:
    pdf = pdftotext.PDF(f)

# %%
 
# Save all text to a txt file.
with open('wp.txt', 'w') as f:
    f.write("\n\n".join(pdf))

# %%
df = pd.read_fwf('wp.txt')

# %%
df[:5]
# Out:
#                                        War and Peace
# 0                                     By Leo Tolstoy
# 1              Translated by Louise and Aylmer Maude
# 2  Published by Planet eBook. Visit the site to d...
# 3    eBooks of classic literature, books and novels.
# 4  This work is licensed under a Creative Commons...

# %%
data = df['War and Peace'].map(word_tokenize)

# %%
data[:5]
# Out:
# 0                                   [By, Leo, Tolstoy]
# 1         [Translated, by, Louise, and, Aylmer, Maude]
# 2    [Published, by, Planet, eBook, ., Visit, the, ...
# 3    [eBooks, of, classic, literature, ,, books, an...
# 4    [This, work, is, licensed, under, a, Creative,...
# Name: War and Peace, dtype: object

# %%
model = Word2Vec(data, size=100, window=5, min_count=1, workers=4)

# %%
model.train(data, total_examples=model.corpus_count, epochs=10)
# Out:
# (4860890, 6904600)

# %%
wv = model.wv

# %%
wv.most_similar('Tsar')
# Out:
# [('Mason', 0.7764177322387695),
#  ('chemist', 0.7738336324691772),
#  ('vicomte', 0.7735103964805603),
#  ('assistant', 0.768223226070404),
#  ('huntsman', 0.7552602291107178),
#  ('wascal', 0.7524303197860718),
#  ('doctor', 0.7503354549407959),
#  ('innkeeper', 0.749898374080658),
#  ('huntsmen', 0.7414214611053467),
#  ('interpreter', 0.7393507957458496)]

# %%
wv.most_similar(positive=['Tsar', 'woman'], negative='Man')
# Out:
# [('prince', 0.5037994980812073),
#  ('edwhether', 0.47035902738571167),
#  ('count', 0.46901440620422363),
#  ('bush-', 0.4548792839050293),
#  ('docto', 0.43852823972702026),
#  ('Egyptians', 0.4247637391090393),
#  ('countess', 0.41030919551849365),
#  ('torment-', 0.4036756157875061),
#  ('doctor', 0.3996453583240509),
#  ('slopin', 0.3887519836425781)]

# %%
wp = ' '.join(df['War and Peace'].values)

# %%
wpsplit = wp.split(' ')

# %%
wpsplit.remove('')

# %%
wpdict = {}
for i in wpsplit:
    if i not in wpdict.keys():
        wpdict[i] =1
    else:
        wpdict[i] += 1

# %%
i_sort = sorted(wpdict, key=wpdict.get, reverse=True)

# %%
stop = list(set(stopwords.words('english')))

# %%
i_sort.remove('')

# %%
more_stop = ['and',
 'of',
 'in',
 'he',
 'was',
 'at',
 'not',
 'as',
 'it',
 'I',
 'but',
 'she',
 'The',
 'said',
 'were',
 'be',
 'which',
 'who',
 'one',
 'He',
 'an',
 'he',
 'as',
 'she',
 'be',
 'He',
 'Planet',
 'eBooks',
 'Free',
 'eBook.com',
 'could',
 'no',
 'will',
 'now',
 'went',
 'But',
 'And',
 'him.',
 'man',
 '‘I',
 'old',
 'him,',
 'She',
 'would',
 'eBook.com',
 'him.',
 'him,',
 'like',
 'came',
 'looked',
 'time',
 'began',
 'know',
 'without',
 'face',
 'thought',
 'felt',
 'see',
 'still',
 'ing',
 'men',
 'It',
 'seemed',
 'left',
 'go',
 'little',
 'come',
 'In',
 'eyes',
 'two',
 'even',
 'must',
 'long',
 'saw',
 'made',
 'something',
 'go',
 'come',
 'always',
 'it.',
 'heard',
 'say',
 'army',
 'and,',
 'young',
 'took',
 'told',
 'don’t',
 'back']

# %%
for i in i_sort:
    if i in stop:
        i_sort.remove(i)

# %%
for i in i_sort:
    if i in more_stop:
        i_sort.remove(i)

# %%
i_sort[:10]
# Out:
# ['Prince',
#  'Pierre',
#  'War',
#  'Natasha',
#  'Andrew',
#  'French',
#  'Peace',
#  'first',
#  'asked',
#  'whole']

# %%
sortdict = {}
for i in i_sort:
    sortdict[i] = wpdict[i]

# %%
sortdict
# Out:
# {'Prince': 1494,
#  'Pierre': 1262,
#  'War': 1161,
#  'Natasha': 685,
#  'Andrew': 672,
#  'French': 671,
#  'Peace': 563,
#  'first': 561,
#  'asked': 547,
#  'whole': 522,
#  'Princess': 517,
#  'Rostov': 442,
#  'Mary': 401,
#  'Moscow': 389,
#  'turned': 385,
#  'Russian': 384,
#  'head': 383,
#  'day': 383,
#  'knew': 380,
#  'room': 380,
#  'never': 376,
#  'When': 371,
#  'A': 369,
#  'away': 365,
#  'Nicholas': 364,
#  'people': 362,
#  'look': 361,
#  'quite': 359,
#  'looking': 358,
#  'They': 356,
#  'her.': 356,
#  'Chapter': 355,
#  'round': 351,
#  'love': 345,
#  'though': 343,
#  'Emperor': 342,
#  'sat': 336,
#  'much': 334,
#  'get': 332,
#  'life': 329,
#  'suddenly': 326,
#  'tell': 325,
#  'take': 322,
#  'it,': 322,
#  'Napoleon': 318,
#  'another': 317,
#  'last': 317,
#  'way': 316,
#  'nothing': 314,
#  'hand': 314,
#  'What': 310,
#  'general': 306,
#  'Kutuzov': 306,
#  'stood': 303,
#  'gave': 301,
#  'His': 300,
#  'On': 298,
#  'Peac': 297,
#  'might': 293,
#  '‘What': 290,
#  'evidently': 290,
#  '‘Yes,': 290,
#  'At': 290,
#  'Anna': 289,
#  'already': 289,
#  'every': 287,
#  'think': 287,
#  'let': 287,
#  '‘You': 281,
#  'good': 276,
#  'yet': 276,
#  'moment': 276,
#  'us': 273,
#  'feeling': 271,
#  'them.': 270,
#  'words': 265,
#  'her,': 264,
#  'Pierre,': 264,
#  'officer': 264,
#  '‘Well,': 261,
#  'put': 260,
#  'make': 260,
#  'going': 259,
#  'new': 257,
#  'toward': 255,
#  'right': 252,
#  'ran': 251,
#  'also': 249,
#  '‘And': 247,
#  'give': 247,
#  '‘But': 244,
#  'seen': 244,
#  'You': 243,
#  'battle': 239,
#  'This': 238,
#  'behind': 238,
#  'replied': 237,
#  're-': 237,
#  'thing': 235,
#  'count': 234,
#  'house': 232,
#  'shall': 231,
#  'taken': 230,
#  'may': 229,
#  'dear': 227,
#  'place': 226,
#  'done': 225,
#  'said,': 224,
#  'understand': 224,
#  'everything': 224,
#  'great': 224,
#  'All': 223,
#  'room.': 222,
#  'three': 222,
#  'side': 222,
#  'called': 219,
#  'Pierre.': 218,
#  'soon': 217,
#  'expression': 216,
#  'sent': 216,
#  'Sonya': 216,
#  'rode': 215,
#  'commander': 214,
#  'soldiers': 214,
#  'As': 213,
#  'smile': 211,
#  'many': 211,
#  'voice': 211,
#  'want': 210,
#  'found': 209,
#  'part': 209,
#  'front': 209,
#  'Denisov': 208,
#  'order': 207,
#  'Count': 206,
#  'prince': 204,
#  '‘The': 204,
#  'whether': 203,
#  'Natasha,': 202,
#  'along': 202,
#  'brought': 200,
#  'talk': 199,
#  'troops': 198,
#  'you,': 197,
#  'got': 197,
#  'taking': 197,
#  'sitting': 196,
#  'There': 195,
#  'moved': 194,
#  'shouted': 193,
#  'After': 192,
#  'position': 192,
#  'among': 191,
#  'countess': 191,
#  'anything': 189,
#  'near': 187,
#  'door': 186,
#  'wished': 185,
#  'drawing': 185,
#  'be-': 184,
#  'lay': 182,
#  'well': 181,
#  'That': 180,
#  'princess': 180,
#  'them,': 180,
#  'tried': 180,
#  'Pea': 178,
#  'Andrew,': 176,
#  'it’s': 176,
#  'things': 175,
#  'white': 175,
#  'Dolokhov': 175,
#  'others': 173,
#  '‘Oh,': 172,
#  'me,': 172,
#  'father': 171,
#  'passed': 171,
#  '‘No,': 171,
#  'entered': 170,
#  'chief': 169,
#  'If': 169,
#  'To': 168,
#  'speak': 168,
#  'turning': 167,
#  'beside': 167,
#  'leave': 167,
#  'word': 166,
#  'Pierre’s': 166,
#  'Petya': 166,
#  'ask': 165,
#  'war': 165,
#  'till': 165,
#  'cried': 164,
#  'Vasili': 163,
#  'understood': 163,
#  'given': 163,
#  'man,': 163,
#  'con-': 163,
#  'received': 162,
#  'can’t': 162,
#  'wish': 161,
#  'noticed': 160,
#  'letter': 160,
#  'became': 159,
#  'eyes,': 159,
#  'Boris': 158,
#  'find': 158,
#  'spoke': 157,
#  'since': 157,
#  'he,': 157,
#  'talking': 155,
#  'horse': 155,
#  'small': 153,
#  'face,': 153,
#  'far': 153,
#  'crowd': 153,
#  'alone': 152,
#  'trying': 152,
#  'glanced': 152,
#  'eyes.': 152,
#  'remained': 151,
#  'really': 150,
#  'wanted': 150,
#  'hands': 149,
#  'kept': 149,
#  'cannot': 148,
#  'large': 148,
#  'I’ll': 147,
#  'longer': 146,
#  'less': 146,
#  'One': 146,
#  'rose': 146,
#  'horses': 146,
#  'Rostov,': 146,
#  'everyone': 145,
#  'stopped': 145,
#  'sound': 145,
#  'Then': 145,
#  'From': 144,
#  'end': 144,
#  'wounded': 144,
#  'movement': 143,
#  'full': 143,
#  'set': 143,
#  'room,': 142,
#  'seeing': 142,
#  'drew': 141,
#  'reached': 140,
#  'met': 139,
#  'standing': 139,
#  'Natasha.': 139,
#  'almost': 138,
#  'thousand': 138,
#  'time,': 138,
#  'several': 138,
#  'question': 137,
#  'How': 137,
#  'officers': 137,
#  'enemy': 137,
#  'in-': 136,
#  'de': 136,
#  'Anatole': 136,
#  'fact': 136,
#  'orders': 136,
#  'days': 135,
#  'held': 135,
#  'happy': 135,
#  'himself,': 135,
#  'next': 134,
#  'Moscow,': 134,
#  'around': 133,
#  'answered': 132,
#  'gone': 132,
#  'wife': 132,
#  'used': 130,
#  'continued': 130,
#  'evening': 129,
#  'cause': 129,
#  'With': 127,
#  'son': 127,
#  '‘How': 127,
#  'news': 127,
#  'won’t': 127,
#  'merely': 127,
#  'army,': 127,
#  'night': 127,
#  'help': 126,
#  'Petersburg': 126,
#  'regiment': 126,
#  'now,': 126,
#  'We': 125,
#  'strange': 125,
#  'mind': 124,
#  'ex-': 124,
#  'smile.': 124,
#  'returned': 124,
#  'saying': 124,
#  'face.': 123,
#  'speaking': 123,
#  'power': 123,
#  'times': 122,
#  'ready': 122,
#  'feel': 122,
#  'able': 122,
#  'life,': 122,
#  'better': 121,
#  'often': 121,
#  'said.': 121,
#  'up,': 121,
#  'coming': 120,
#  'past': 120,
#  'that,': 120,
#  'grew': 120,
#  'soldier': 120,
#  'then,': 119,
#  'terrible': 119,
#  'God': 118,
#  'arms': 118,
#  'hear': 118,
#  'Mademoiselle': 118,
#  '‘He': 118,
#  'So': 117,
#  'holding': 117,
#  'half': 117,
#  'action': 117,
#  '‘It': 116,
#  'become': 115,
#  'especially': 115,
#  'afraid': 115,
#  'state': 115,
#  'himself.': 115,
#  'fire': 115,
#  'For': 115,
#  '‘If': 114,
#  'table': 114,
#  'morning': 114,
#  'kissed': 113,
#  'that’s': 113,
#  'on,': 113,
#  'he.': 113,
#  'Only': 113,
#  'hundred': 113,
#  'Natasha’s': 113,
#  'road': 113,
#  'free': 112,
#  'known': 112,
#  'men,': 112,
#  'listened': 112,
#  'across': 112,
#  'followed': 112,
#  'best': 111,
#  'third': 111,
#  '‘Ah,': 111,
#  '‘Why': 111,
#  'former': 111,
#  'Having': 111,
#  'certain': 111,
#  'is,': 110,
#  'village': 109,
#  '‘It’s': 109,
#  'ed': 109,
#  'black': 109,
#  'led': 109,
#  'forward': 109,
#  'know,': 108,
#  'tears': 108,
#  'different': 108,
#  'read': 108,
#  'Marya': 107,
#  'arm': 107,
#  'showed': 107,
#  'Andrew.': 107,
#  'hand.': 107,
#  'voices': 107,
#  'conversation': 106,
#  'anyone': 106,
#  'faces': 106,
#  'fell': 106,
#  'loved': 106,
#  'ever': 104,
#  'impossible': 104,
#  'another,': 104,
#  'field': 104,
#  'force': 103,
#  'un-': 103,
#  'tone': 102,
#  'smiled': 102,
#  'man’s': 102,
#  'necessary': 102,
#  'important': 102,
#  'giving': 102,
#  'heart': 102,
#  'whose': 101,
#  'opened': 101,
#  'voice.': 101,
#  'ordered': 101,
#  'human': 101,
#  'French,': 100,
#  'meet': 100,
#  'show': 100,
#  'expressed': 100,
#  'happened': 100,
#  'ly': 99,
#  'away.': 99,
#  'appeared': 99,
#  'lost': 99,
#  'matter': 99,
#  'making': 99,
#  'light': 99,
#  'Countess': 99,
#  'believe': 98,
#  'raised': 98,
#  'close': 98,
#  'who,': 97,
#  'smiling': 97,
#  'need': 97,
#  'steps': 97,
#  'ought': 97,
#  'Russians': 97,
#  'history': 97,
#  'adjutant': 97,
#  'high': 96,
#  'waiting': 96,
#  'military': 96,
#  'Nicholas,': 96,
#  'carried': 96,
#  'Mary,': 96,
#  'sometimes': 95,
#  'answer': 95,
#  'there,': 95,
#  'kind': 95,
#  'air': 95,
#  'possible': 95,
#  'clear': 95,
#  'on.': 95,
#  'beyond': 95,
#  'woman': 94,
#  'thinking': 94,
#  'upon': 94,
#  'hair': 94,
#  'up.': 94,
#  'immediately': 93,
#  'asking': 93,
#  'moving': 93,
#  'straight': 93,
#  'glad': 93,
#  'struck': 93,
#  'cold': 93,
#  'Moscow.': 92,
#  'second': 92,
#  'pressed': 92,
#  'voice,': 92,
#  'Sonya,': 92,
#  'Emperor’s': 92,
#  'galloped': 92,
#  'hand,': 91,
#  'tion': 91,
#  'ten': 91,
#  'repeated': 91,
#  'say,': 91,
#  'home': 91,
#  'later': 91,
#  'either': 90,
#  'mother': 90,
#  'running': 90,
#  'quickly': 90,
#  'frightened': 89,
#  'run': 89,
#  'someone': 89,
#  'remembered': 89,
#  'dinner': 89,
#  'turn': 89,
#  'all,': 88,
#  'life.': 88,
#  'unable': 88,
#  'head.': 88,
#  'red': 88,
#  'strength': 88,
#  'It’s': 88,
#  'short': 87,
#  'you.': 87,
#  'present': 87,
#  'gazed': 87,
#  'staff': 87,
#  'day,': 87,
#  'count,': 87,
#  'command': 87,
#  'historians': 87,
#  '‘We': 86,
#  'this,': 86,
#  'soul': 86,
#  'away,': 86,
#  'I’m': 86,
#  'time.': 86,
#  'Denisov,': 86,
#  'head,': 85,
#  'reason': 85,
#  'Though': 85,
#  'rather': 85,
#  'Helene': 85,
#  'usual': 85,
#  'open': 85,
#  'spent': 85,
#  'four': 85,
#  'decided': 84,
#  'again,': 84,
#  'Now': 84,
#  'world': 84,
#  'com-': 84,
#  'Napoleon’s': 84,
#  'killed': 84,
#  'Andrew’s': 84,
#  'fresh': 84,
#  'angry': 84,
#  'girl': 83,
#  'me.': 83,
#  'sides': 83,
#  'bad': 83,
#  'right,': 83,
#  'considered': 82,
#  'Why': 82,
#  'asked.': 82,
#  'wrote': 82,
#  'presence': 82,
#  'father’s': 82,
#  'door.': 82,
#  'death': 82,
#  'else': 81,
#  'That’s': 81,
#  'years': 81,
#  'Alexander': 81,
#  'Bagration': 81,
#  'Alpatych': 81,
#  'added': 80,
#  'closed': 80,
#  'Her': 80,
#  'meaning': 80,
#  'seized': 80,
#  'women': 80,
#  'neither': 79,
#  'talked': 79,
#  'fine': 79,
#  'doctor': 79,
#  'aim': 79,
#  'fixed': 79,
#  'smoke': 79,
#  'family': 78,
#  'added,': 78,
#  'case': 78,
#  'pleasure': 78,
#  'you,’': 78,
#  'rushed': 78,
#  'Rostov.': 78,
#  'fear': 78,
#  'says': 78,
#  'drove': 78,
#  'course': 78,
#  'Mary.': 78,
#  'honor': 77,
#  'least': 77,
#  'there.': 77,
#  'sight': 77,
#  'feet': 77,
#  'handsome': 77,
#  'knowing': 77,
#  'seem': 77,
#  'shouting': 77,
#  'changed': 76,
#  'attack': 76,
#  'officer,': 76,
#  'single': 76,
#  'money': 76,
#  'work': 75,
#  'pleased': 75,
#  'return': 75,
#  '‘and': 75,
#  'seems': 75,
#  'yes,': 75,
#  'knows': 75,
#  'various': 75,
#  'thought.': 75,
#  'call': 74,
#  'dark': 74,
#  'de-': 74,
#  'another.': 74,
#  'reply': 74,
#  'Just': 74,
#  'expected': 74,
#  'attention': 74,
#  'line': 74,
#  'getting': 74,
#  'remember': 74,
#  '‘A': 74,
#  'thoughts': 74,
#  'husband': 73,
#  'spite': 73,
#  'hardly': 73,
#  'covered': 73,
#  'again.': 73,
#  'interrupted': 73,
#  'guns': 73,
#  '‘My': 72,
#  'lips': 72,
#  'clearly': 72,
#  'five': 72,
#  'body': 72,
#  'keep': 72,
#  'remain': 72,
#  'coat': 72,
#  'man.': 72,
#  'meeting': 72,
#  'middle': 72,
#  'pale': 72,
#  'occupied': 72,
#  'er': 72,
#  'before,': 72,
#  'Napoleon,': 72,
#  'me,’': 71,
#  'Kutuzov’s': 71,
#  'name': 71,
#  'bring': 71,
#  'low': 71,
#  '‘but': 71,
#  'live': 71,
#  'countess,': 71,
#  'within': 71,
#  'dressing': 71,
#  'events': 71,
#  'activity': 71,
#  'peasants': 71,
#  'Balashev': 71,
#  'Well,': 70,
#  'sure': 70,
#  'rest': 70,
#  'change': 70,
#  'living': 70,
#  'out,': 70,
#  'deep': 70,
#  'soldiers,': 70,
#  'it?’': 69,
#  'Russia': 69,
#  'smile,': 69,
#  'Pe': 69,
#  'special': 69,
#  'bridge': 69,
#  'particularly': 69,
#  'carriage': 69,
#  'way,': 69,
#  'beginning': 69,
#  'sense': 68,
#  'pleasant': 68,
#  'prepared': 68,
#  'Not': 68,
#  'too,': 68,
#  'passing': 68,
#  'prisoners': 68,
#  'everybody': 68,
#  'fellow': 68,
#  'sounds': 68,
#  'lived': 68,
#  'Mikhaylovna': 68,
#  'questions': 68,
#  'pointing': 68,
#  'happiness': 68,
#  '‘They': 67,
#  '‘Do': 67,
#  '‘That’s': 67,
#  'Bolkonski': 67,
#  'placed': 67,
#  'difficult': 67,
#  'leaving': 67,
#  'way.': 67,
#  'rapidly': 67,
#  'Some': 67,
#  'town': 67,
#  'meant': 67,
#  'flank': 67,
#  'conception': 67,
#  'Rostopchin': 67,
#  'day.': 66,
#  'point': 66,
#  'formed': 66,
#  'contrary': 66,
#  'legs': 66,
#  'glancing': 66,
#  'study': 66,
#  'blue': 66,
#  'corner': 66,
#  'count’s': 66,
#  'brother': 66,
#  'view': 66,
#  'presented': 66,
#  'try': 65,
#  'Pavlovna': 65,
#  'instead': 65,
#  'ball': 65,
#  'thin': 65,
#  'listening': 65,
#  'real': 65,
#  'in,': 65,
#  'walked': 65,
#  'lying': 65,
#  'therefore': 65,
#  'farther': 65,
#  'horse,': 65,
#  'liked': 65,
#  'silent': 64,
#  'said:': 64,
#  'hope': 64,
#  'dressed': 64,
#  '‘There': 64,
#  'evident': 64,
#  'Frenchman': 64,
#  'friend': 64,
#  'out.': 64,
#  'together': 64,
#  'French.': 64,
#  'hard': 64,
#  'hussars': 64,
#  'not,': 64,
#  'experienced': 64,
#  'cannon': 64,
#  'thought,': 63,
#  'daughter': 63,
#  'true': 63,
#  'wife,': 63,
#  'beautiful': 63,
#  'fall': 63,
#  'looks': 63,
#  'window': 63,
#  'house,': 63,
#  'was,': 62,
#  'one’s': 62,
#  'gray': 62,
#  'plan': 62,
#  'princess,': 62,
#  'Kutuzov,': 62,
#  'freedom': 62,
#  'opinion': 62,
#  'except': 62,
#  'continually': 62,
#  'onto': 62,
#  'down,': 62,
#  'Nicholas.': 62,
#  'affairs': 62,
#  'cavalry': 62,
#  'While': 62,
#  'crossed': 62,
#  'Bald': 62,
#  'laws': 62,
#  'begun': 62,
#  'result': 62,
#  'wearing': 61,
#  'grown': 61,
#  'lifted': 61,
#  'finished': 61,
#  'probably': 61,
#  'remarked': 61,
#  'wishing': 61,
#  'use': 61,
#  'ter': 61,
#  'threw': 61,
#  'simply': 61,
#  'greater': 61,
#  'filled': 61,
#  'subject': 61,
#  'generals': 61,
#  'Austrian': 61,
#  '‘Now': 60,
#  'an-': 60,
#  'dress': 60,
#  'addressing': 60,
#  'telling': 60,
#  'bed': 60,
#  'marry': 60,
#  'move': 60,
#  'hussar': 60,
#  'hold': 60,
#  'arrived': 60,
#  'boy': 60,
#  'house.': 60,
#  'forget': 60,
#  'desire': 60,
#  'he’s': 60,
#  'peasant': 60,
#  'society': 59,
#  'despite': 59,
#  'nearer': 59,
#  'it,’': 59,
#  'late': 59,
#  'An-': 59,
#  'express': 59,
#  'sorry': 59,
#  'regard': 59,
#  'peace': 59,
#  'drawn': 59,
#  'bent': 59,
#  'send': 59,
#  'dis-': 59,
#  'army.': 59,
#  'number': 59,
#  'calm': 58,
#  'Emperor,': 58,
#  'approached': 58,
#  'brilliant': 58,
#  'exclaimed': 58,
#  'forces': 58,
#  'Your': 58,
#  'Oh,': 58,
#  'growing': 58,
#  'plain': 58,
#  'Yes,': 58,
#  'one,': 58,
#  'hearing': 58,
#  'colonel': 58,
#  'Berg': 58,
#  '‘To': 58,
#  'according': 58,
#  'Rostovs': 58,
#  'ground': 58,
#  'Smolensk': 58,
#  'Borodino': 58,
#  'means': 57,
#  'occurred': 57,
#  'duty': 57,
#  'spread': 57,
#  'some-': 57,
#  'whispered': 57,
#  'interest': 57,
#  'enter': 57,
#  'reading': 57,
#  'so,': 57,
#  'Dolokhov,': 57,
#  'pointed': 57,
#  'father,': 57,
#  'silently': 57,
#  'learned': 57,
#  'event': 57,
#  'carts': 57,
#  'poor': 56,
#  'stand': 56,
#  'bowed': 56,
#  'people,': 56,
#  'bare': 56,
#  'gazing': 56,
#  'so.': 56,
#  'shown': 56,
#  'perhaps': 56,
#  'Rostovs’': 56,
#  'Ros-': 56,
#  'before.': 56,
#  'us,': 56,
#  'surrounded': 56,
#  'Bourienne': 56,
#  'riding': 56,
#  'campaign': 56,
#  'Cossacks': 56,
#  'expecting': 55,
#  'general,': 55,
#  'latter': 55,
#  'me!’': 55,
#  'No': 55,
#  'ment': 55,
#  'imagine': 55,
#  'fight': 55,
#  'handed': 55,
#  'sit': 55,
#  'During': 55,
#  'General': 55,
#  'involuntarily': 55,
#  'uniform': 55,
#  'men.': 55,
#  'enemy’s': 55,
#  'firing': 55,
#  'retreat': 55,
#  'law': 55,
#  'written': 54,
#  'prince,': 54,
#  '‘the': 54,
#  'bright': 54,
#  'glance': 54,
#  'effect': 54,
#  'Boris,': 54,
#  'silent.': 54,
#  'pushed': 54,
#  'following': 54,
#  'notice': 54,
#  'caught': 54,
#  'idea': 54,
#  'pass': 54,
#  'door,': 54,
#  'service': 54,
#  'avoid': 54,
#  '‘Where': 54,
#  '‘Don’t': 53,
#  'which,': 53,
#  'quiet': 53,
#  'words,': 53,
#  'group': 53,
#  'lit': 53,
#  'she,': 53,
#  'My': 53,
#  'year': 53,
#  'consider': 53,
#  'actions': 53,
#  '‘All': 53,
#  '‘Is': 53,
#  'noticing': 53,
#  'surprised': 53,
#  'An': 53,
#  '‘So': 53,
#  'country': 53,
#  'future': 53,
#  'personal': 53,
#  'business': 53,
#  'Do': 52,
#  'son,': 52,
#  'children': 52,
#  'company': 52,
#  'back,': 52,
#  'touched': 52,
#  'broken': 52,
#  'No,': 52,
#  'Don’t': 52,
#  'infantry': 52,
#  'hands,': 52,
#  'herself,': 52,
#  'please': 52,
#  'ac-': 52,
#  'condition': 52,
#  'foot': 52,
#  'caused': 52,
#  'account': 52,
#  'cut': 52,
#  'possibility': 52,
#  'do,': 51,
#  'sad': 51,
#  'act': 51,
#  'settled': 51,
#  'moment,': 51,
#  'Before': 51,
#  'hour': 51,
#  'Two': 51,
#  'understanding': 51,
#  'it?': 51,
#  'addressed': 51,
#  'effort': 51,
#  'nearly': 51,
#  'strong': 51,
#  'These': 51,
#  'well,': 51,
#  'laid': 51,
#  'ranks': 51,
#  'all.': 51,
#  'Rostov’s': 51,
#  'stepped': 51,
#  'seven': 51,
#  'Dmitrievna': 51,
#  'others,': 51,
#  'silence': 51,
#  'Mary’s': 51,
#  'stay': 51,
#  'him-': 50,
#  'fate': 50,
#  'certainly': 50,
#  'amid': 50,
#  'child': 50,
#  'heard.': 50,
#  'begin': 50,
#  'here,': 50,
#  'figure': 50,
#  'recognized': 50,
#  'shook': 50,
#  'relations': 50,
#  'sort': 50,
#  'it!’': 50,
#  'regiment,': 50,
#  'down.': 50,
#  'kill': 50,
#  'you?’': 50,
#  'cap': 50,
#  'miles': 50,
#  'say.': 50,
#  'direction': 50,
#  'unknown': 50,
#  'Cossack': 50,
#  'court': 49,
#  'consciousness': 49,
#  'cross': 49,
#  'explain': 49,
#  'affair': 49,
#  'highest': 49,
#  'ev-': 49,
#  'big': 49,
#  'table.': 49,
#  'path': 49,
#  'pity': 49,
#  'you.’': 49,
#  'rising': 49,
#  'step': 49,
#  ...}

# %%
top20 = list(sortdict.keys())[:20]

# %%
top20val = list(sortdict.values())[:20]

# %%
plt.figure(figsize = (15,9))
plt.bar(top20, top20val)
plt.xticks(rotation=60)
plt.show()
